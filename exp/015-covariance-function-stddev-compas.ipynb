# %% [markdown]
# # Testing with actual distance covariance on COMPAS data

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))

if module_path not in sys.path:
    sys.path.append(module_path)

import numpy as np
import multiprocessing as mp
from src.util import load_dataset
from src.feature_map import IdentityFeatureMap
from src.functions import cost_utility, demographic_parity
from src.plotting import plot_mean, plot_median
from src.training import train
from src.distribution import ResamplingDistribution

# %% [markdown]
# ## Definition of fairness function

# %%
def calc_covariance(x, s, policy, ips_weights):    
    phi = policy.feature_map(policy._extract_features(x, s))
    distance = np.matmul(phi, policy.theta).reshape(-1, 1)
    
    if ips_weights is not None:
        mu_s = np.mean(s * ips_weights, axis=0)
        distance *= ips_weights
    else:
        mu_s = np.mean(s, axis=0)

    covariance = (s - mu_s) * distance
    distance_stddev = distance.std() if distance.std() != 0 else 1
    
    return covariance, distance_stddev

def fairness_gradient_function(**fairness_kwargs):
    policy = fairness_kwargs["policy"]
    x = fairness_kwargs["x"]
    s = fairness_kwargs["s"]
    ips_weights = fairness_kwargs["ips_weights"]
    
    covariance, distance_stddev = calc_covariance(x, s, policy, ips_weights)

    log_policy_gradient = policy.log_policy_gradient(x, s)
    covariance_grad = log_policy_gradient * covariance

    return np.mean(covariance_grad, axis=0) / distance_stddev

def fairness_function(**fairness_kwargs):
    policy = fairness_kwargs["policy"]
    x = fairness_kwargs["x"]
    s = fairness_kwargs["s"]
    ips_weights = fairness_kwargs["ips_weights"]
    
    covariance, distance_stddev = calc_covariance(x, s, policy, ips_weights)
    return np.mean(covariance, axis=0) / distance_stddev

# %% [markdown]
# ## Parameterization

# %%
bias = True
distribution = ResamplingDistribution(bias=bias, dataset=load_dataset("../dat/compas/compas.npz"), test_percentage=0.2)
dim_theta = distribution.feature_dim

def util_func(**util_params):
    util = cost_utility(cost_factor=0.6, **util_params)
    return util

training_parameters = {    
    'save_path': './',
    'model':{
        'benefit_function': demographic_parity,
        'utility_function': util_func,
        'fairness_function': fairness_function,
        'fairness_gradient_function': fairness_gradient_function,
        'feature_map': IdentityFeatureMap(dim_theta),
        'learn_on_entire_history': False,
        'use_sensitve_attributes': False,
        'bias': bias,
        'initial_theta': np.zeros((dim_theta))
    },
    'parameter_optimization': {
        'time_steps':200,
        'epochs': 10,
        'batch_size':64,
        'learning_rate': 0.01,
        'decay_rate': 1,
        'decay_step': 10000,
        'num_decisions': 4096
    },
    'data': {
        'distribution': distribution,
        'num_test_samples': None
    }
}

# %%
training_parameters["experiment_name"] = "exp-015-no-fairness"
training_parameters["model"]["initial_lambda"] = 0.0

statistics, _, run_path = train(training_parameters, iterations=30, asynchronous=True)

plot_mean(statistics, "{}/results_mean_lambdas.png".format(run_path))
plot_median(statistics, "{}/results_median_lambdas.png".format(run_path))
# Out:
# ---------- Single training run for fixed lambda ----------

# %%
training_parameters["experiment_name"] = "exp-015-lambda-sweep"
lambdas = np.geomspace(0.1, 100, endpoint=True, num=20)
lambdas = np.insert(arr=lambdas, obj=0, values=[0.0])
training_parameters["model"]["initial_lambda"] = lambdas

statistics, _, run_path = train(training_parameters, iterations=30, asynchronous=True)

plot_mean(statistics, "{}/results_mean_lambdas.png".format(run_path))
plot_median(statistics, "{}/results_median_lambdas.png".format(run_path))
# Out:
# ---------- Training with fixed lambdas ----------

# %%
training_parameters["experiment_name"] = "exp-015-dual-gradient"
training_parameters["model"]["initial_lambda"] = 0.0
training_parameters["lagrangian_optimization"] = {
    'iterations': 20,
    'epochs': 1,
    'batch_size':256,
    'learning_rate': 0.00001,
    'decay_rate': 1,
    'decay_step': 10000,
    'num_decisions': 128 * 256
}

statistics, _, run_path = train(training_parameters, iterations=30, asynchronous=True)

plot_mean(statistics, "{}/results_mean_lambdas.png".format(run_path))
plot_median(statistics, "{}/results_median_lambdas.png".format(run_path))
# Out:
# ---------- Training both theta and lambda ----------
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/fkretschmar/miniconda3/envs/masters-thesis/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/fkretschmar/Documents/master-thesis/src/training.py", line 24, in _training_iteration
#     for decisions_over_time, model_parameters, fairness_over_time in training_method(training_parameters):
#   File "/home/fkretschmar/Documents/master-thesis/src/consequential_learning.py", line 235, in train
#     yield self._train_model_parameters(policy, optimizer, training_parameters)
#   File "/home/fkretschmar/Documents/master-thesis/src/consequential_learning.py", line 128, in _train_model_parameters
#     decisions_over_time = policy(x_test, s_test).reshape(-1, 1)
#   File "/home/fkretschmar/Documents/master-thesis/src/policy.py", line 40, in __call__
#     probability = self._probability(features)
#   File "/home/fkretschmar/Documents/master-thesis/src/policy.py", line 164, in _probability
#     return sigmoid(np.matmul(self.feature_map(features), self.theta))
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 2 is different from 6)
# """
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-e5ff28aec345> in <module>
#      11 }
#      12
# ---> 13 statistics, _, run_path = train(training_parameters, iterations=30, asynchronous=True)
#      14
#      15 plot_mean(statistics, "{}/results_mean_lambdas.png".format(run_path))
#
# ~/Documents/master-thesis/src/training.py in train(training_parameters, iterations, asynchronous)
#     271         overall_statistics = MultiStatistics("linear", lamda_iterations, "Lambda Training Iteration")
#     272
# --> 273         statistics, model_parameters = trainer.train_over_iterations(current_training_parameters, training_algorithm.train, iterations, asynchronous)
#     274
#     275         for num_lambda, statistic in enumerate(statistics):
#
# ~/Documents/master-thesis/src/training.py in train_over_iterations(self, training_parameters, training_method, iterations, asynchronous)
#      71
#      72             for result in apply_results:
# ---> 73                 results_per_iterations.append(result.get())
#      74         else:
#      75             results_per_iterations = []
#
# ~/miniconda3/envs/masters-thesis/lib/python3.7/multiprocessing/pool.py in get(self, timeout)
#     655             return self._value
#     656         else:
# --> 657             raise self._value
#     658
#     659     def _set(self, i, obj):
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 2 is different from 6)
